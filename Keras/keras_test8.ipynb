# %%
from PIL import Image
import os, glob, numpy as np
from sklearn.model_selection import train_test_split

caltech_dir = "/Users/jiwon/Desktop/female"
categories = ["cat","dog","rodent"]
nb_classes = len(categories)

image_w = 64
image_h = 64

pixels = image_h * image_w * 3

X = []
y = []

for idx, cat in enumerate(categories):
    
    #one-hot 돌리기.
    label = [0 for i in range(nb_classes)]
    label[idx] = 1

    image_dir = caltech_dir + "/" + cat
    files = glob.glob(image_dir+"/*.jpg")
    print(cat, " 파일 길이 : ", len(files))
    for i, f in enumerate(files):
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((image_w, image_h))
        data = np.asarray(img)

        X.append(data)
        y.append(label)

        if i % 700 == 0:
            print(cat, " : ", f)
X = np.array(X)
y = np.array(y)
#1 0 0 0 이면 airplanes
#0 1 0 0 이면 buddha 이런식


X_train, X_test, y_train, y_test = train_test_split(X, y)
xy = (X_train, X_test, y_train, y_test)
np.save("/Users/jiwon/Desktop/numpy_data/multi_image_data.npy", xy)

print("ok", len(y))
# Out:
# cat  파일 길이 :  602
# cat  :  /Users/jiwon/Desktop/female/cat/823.jpg
# dog  파일 길이 :  579
# dog  :  /Users/jiwon/Desktop/female/dog/63.jpg
# rodent  파일 길이 :  339
# rodent  :  /Users/jiwon/Desktop/female/rodent/rodent130.jpg
# ok 1520

# %%
import os, glob, numpy as np
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import keras.backend.tensorflow_backend as K

import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

X_train, X_test, y_train, y_test = np.load('/Users/jiwon/Desktop/numpy_data/multi_image_data.npy',allow_pickle=True)
print(X_train.shape)
print(X_train.shape[0])
# Out:
# Using TensorFlow backend.
# /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (1140, 64, 64, 3)
# 1140

# %%
categories = ["cat","dog","rodent"]
nb_classes = len(categories)

#일반화
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %%
with K.tf_ops.device('/device:GPU:0'):
    model = Sequential()
    model.add(Conv2D(32, (3,3), padding="same", input_shape=X_train.shape[1:], activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))
    
    model.add(Conv2D(64, (3,3), padding="same", activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))
    
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model_dir = './model'
    
    if not os.path.exists(model_dir):
        os.mkdir(model_dir)
    
    model_path = model_dir + '/multi_img_classification.model'
    checkpoint = ModelCheckpoint(filepath=model_path , monitor='val_loss', verbose=1, save_best_only=True)
    early_stopping = EarlyStopping(monitor='val_loss', patience=6)
# Out:
# WARNING:tensorflow:From /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               4194560
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 4,214,723
# Trainable params: 4,214,723
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, validation_split=0.2, batch_size=32, epochs=50, callbacks=[checkpoint, early_stopping])
# Out:
# WARNING:tensorflow:From /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 912 samples, validate on 228 samples
# Epoch 1/50
# 912/912 [==============================] - 5s 5ms/step - loss: 1.1831 - accuracy: 0.4035 - val_loss: 1.0746 - val_accuracy: 0.4123
#
# Epoch 00001: val_loss improved from inf to 1.07464, saving model to ./model/multi_img_classification.model
# Epoch 2/50
# 912/912 [==============================] - 4s 4ms/step - loss: 1.0639 - accuracy: 0.4386 - val_loss: 1.0668 - val_accuracy: 0.4167
#
# Epoch 00002: val_loss improved from 1.07464 to 1.06684, saving model to ./model/multi_img_classification.model
# Epoch 3/50
# 912/912 [==============================] - 4s 4ms/step - loss: 1.0441 - accuracy: 0.4781 - val_loss: 1.0348 - val_accuracy: 0.4298
#
# Epoch 00003: val_loss improved from 1.06684 to 1.03481, saving model to ./model/multi_img_classification.model
# Epoch 4/50
# 912/912 [==============================] - 4s 4ms/step - loss: 1.0126 - accuracy: 0.4868 - val_loss: 1.0337 - val_accuracy: 0.4474
#
# Epoch 00004: val_loss improved from 1.03481 to 1.03366, saving model to ./model/multi_img_classification.model
# Epoch 5/50
# 912/912 [==============================] - 4s 4ms/step - loss: 0.9906 - accuracy: 0.5110 - val_loss: 1.0063 - val_accuracy: 0.4430
#
# Epoch 00005: val_loss improved from 1.03366 to 1.00626, saving model to ./model/multi_img_classification.model
# Epoch 6/50
# 912/912 [==============================] - 4s 5ms/step - loss: 0.9482 - accuracy: 0.5493 - val_loss: 0.9947 - val_accuracy: 0.4912
#
# Epoch 00006: val_loss improved from 1.00626 to 0.99471, saving model to ./model/multi_img_classification.model
# Epoch 7/50
# 912/912 [==============================] - 4s 5ms/step - loss: 0.9308 - accuracy: 0.5658 - val_loss: 1.0058 - val_accuracy: 0.4298
#
# Epoch 00007: val_loss did not improve from 0.99471
# Epoch 8/50
# 912/912 [==============================] - 4s 5ms/step - loss: 0.8918 - accuracy: 0.5844 - val_loss: 0.9852 - val_accuracy: 0.5219
#
# Epoch 00008: val_loss improved from 0.99471 to 0.98520, saving model to ./model/multi_img_classification.model
# Epoch 9/50
# 912/912 [==============================] - 4s 5ms/step - loss: 0.8502 - accuracy: 0.6151 - val_loss: 1.0019 - val_accuracy: 0.5000
#
# Epoch 00009: val_loss did not improve from 0.98520
# Epoch 10/50
# 912/912 [==============================] - 4s 5ms/step - loss: 0.7931 - accuracy: 0.6491 - val_loss: 0.9929 - val_accuracy: 0.4825
#
# Epoch 00010: val_loss did not improve from 0.98520
# Epoch 11/50
# 912/912 [==============================] - 4s 4ms/step - loss: 0.7620 - accuracy: 0.6711 - val_loss: 1.0473 - val_accuracy: 0.4649
#
# Epoch 00011: val_loss did not improve from 0.98520
# Epoch 12/50
# 912/912 [==============================] - 4s 4ms/step - loss: 0.7342 - accuracy: 0.6787 - val_loss: 0.9996 - val_accuracy: 0.5307
#
# Epoch 00012: val_loss did not improve from 0.98520
# Epoch 13/50
# 912/912 [==============================] - 4s 5ms/step - loss: 0.6531 - accuracy: 0.7325 - val_loss: 1.0139 - val_accuracy: 0.5219
#
# Epoch 00013: val_loss did not improve from 0.98520
# Epoch 14/50
# 912/912 [==============================] - 4s 4ms/step - loss: 0.6008 - accuracy: 0.7544 - val_loss: 1.0494 - val_accuracy: 0.5175
#
# Epoch 00014: val_loss did not improve from 0.98520

# %%
print("정확도 : %.4f" % (model.evaluate(X_test, y_test)[1]))
# Out:
# 380/380 [==============================] - 0s 858us/step
# 정확도 : 0.4579

# %%
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))

plt.plot(x_len, y_vloss, marker='.', c='red', label='val_set_loss')
plt.plot(x_len, y_loss, marker='.', c='blue', label='train_set_oss')
plt.legend()
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()
plt.show()

# %%
from PIL import Image
import os, glob, numpy as np
from keras.models import load_model
caltech_dir = "/Users/jiwon/Desktop/female/cat"
# caltech_dir = "./multi_img_data/imgs_others_test"
image_w = 64
image_h = 64

pixels = image_h * image_w * 3

X = []
filenames = []
files = glob.glob(caltech_dir+"/*.*")
for i, f in enumerate(files):
    img = Image.open(f)
    img = img.convert("RGB")
    img = img.resize((image_w, image_h))
    data = np.asarray(img)
    filenames.append(f)
    X.append(data)
    
X = np.array(X)


# np.resize(img, (-1, <image shape>)
# model = load_model('./model/multi_img_classification.model')
#model = load_model('/Users/jiwon/model/multi_img_classification.model')
model = load_model('./model/multi_img_classification.model')
# X = X.reshape(X_train.shape[0], 720, 1280, 1)
prediction = model.predict(X)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
cnt = 0

#이 비교는 그냥 파일들이 있으면 해당 파일과 비교. 카테고리와 함께 비교해서 진행하는 것은 _4 파일.
for i in prediction:
    pre_ans = i.argmax()  # 예측 레이블
    print(i)
    print(pre_ans)
    pre_ans_str = ''
    if pre_ans == 0: pre_ans_str = "cat"
    elif pre_ans == 1: pre_ans_str = "dog"
    else : pre_ans_str = "rodent"
    if i[0] >= 0.8 : print("해당 "+filenames[cnt].split("\\")[0]+"이미지는 "+pre_ans_str+"로 추정됩니다.")
    if i[1] >= 0.8: print("해당 "+filenames[cnt].split("\\")[0]+"이미지는 "+pre_ans_str+"으로 추정됩니다.")
    if i[2] >= 0.8: print("해당 "+filenames[cnt].split("\\")[0]+"이미지는 "+pre_ans_str+"으로 추정됩니다.")
    cnt += 1
    # print(i.argmax()) #얘가 레이블 [1. 0. 0.] 이런식으로 되어 있는 것을 숫자로 바꿔주는 것.
    # 즉 얘랑, 나중에 카테고리 데이터 불러와서 카테고리랑 비교를 해서 같으면 맞는거고, 아니면 틀린거로 취급하면 된다.
# Out:
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/823.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/837.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/604.jpg이미지는 dog으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/162.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/88.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/360.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/374.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/599.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/228.jpg이미지는 dog으로 추정됩니다.
# [0.005 0.000 0.995]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/214.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/566.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/200.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/758.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/764.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/765.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/759.jpg이미지는 cat로 추정됩니다.
# [0.974 0.026 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/942.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/201.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/598.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/375.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/361.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/349.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/611.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/89.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/605.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/163.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/639.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/836.jpg이미지는 cat로 추정됩니다.
# [0.042 0.000 0.958]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/76.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/62.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/834.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/820.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/808.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/149.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/613.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/175.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/161.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/388.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/439.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/363.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/559.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/203.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/571.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/217.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/940.jpg이미지는 dog으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/954.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/767.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/772.jpg이미지는 dog으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/941.jpg이미지는 rodent으로 추정됩니다.
# [0.006 0.994 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/570.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/216.jpg이미지는 dog으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/202.jpg이미지는 rodent으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/564.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/558.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/606.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/612.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/174.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/809.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/49.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/821.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/61.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/835.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/75.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/71.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/831.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/65.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/170.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/602.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/164.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/158.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/399.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/372.jpg이미지는 dog으로 추정됩니다.
# [0.000 0.155 0.845]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/366.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/428.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/560.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/951.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/789.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/762.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/776.jpg이미지는 cat로 추정됩니다.
# [0.637 0.000 0.363]
# 0
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/763.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/788.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/549.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/575.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/561.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/207.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/159.jpg이미지는 cat로 추정됩니다.
# [0.000 0.993 0.007]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/165.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/171.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/617.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/64.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/818.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/58.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/826.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/832.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/167.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/601.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/99.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/173.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/629.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/365.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/371.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/417.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/588.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/577.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/563.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/239.jpg이미지는 cat로 추정됩니다.
# [0.045 0.000 0.955]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/775.jpg이미지는 rodent으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/761.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/748.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/760.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/947.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/238.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/204.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/562.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/358.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/370.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/402.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/614.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/172.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/166.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/600.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/73.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/199.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/827.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/9.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/698.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/840.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/14.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/854.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/868.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/129.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/101.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/667.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/673.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/459.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/465.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/303.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/317.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/539.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/511.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/505.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/920.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/908.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/713.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/706.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/712.jpg이미지는 cat로 추정됩니다.
# [0.008 0.000 0.992]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/262.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/504.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/276.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/538.jpg이미지는 dog으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/289.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/316.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/470.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/458.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/672.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/114.jpg이미지는 dog으로 추정됩니다.
# [0.939 0.061 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/100.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/666.jpg이미지는 dog으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/896.jpg이미지는 rodent으로 추정됩니다.
# [0.974 0.026 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/128.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/882.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/869.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/855.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/841.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/699.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/857.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/843.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/880.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/670.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/664.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/102.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/499.jpg이미지는 cat로 추정됩니다.
# [0.000 0.999 0.001]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/328.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/472.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/314.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/300.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/506.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/260.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/738.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/704.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/710.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/711.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/739.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/936.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/922.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/507.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/261.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/301.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/467.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/473.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/315.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/665.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/103.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/117.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/671.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/659.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/881.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/895.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/842.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/856.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/12.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/846.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/675.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/661.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/891.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/649.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/311.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/463.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/305.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/339.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/265.jpg이미지는 rodent으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/503.jpg이미지는 rodent으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/271.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/259.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/932.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/701.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/729.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/728.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/714.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/700.jpg이미지는 rodent으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/927.jpg이미지는 rodent으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/258.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/270.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/264.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/502.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/338.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/304.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/310.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/476.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/489.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/890.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/660.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/674.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/112.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/847.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/853.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/845.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/689.jpg이미지는 cat로 추정됩니다.
# [0.973 0.027 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/662.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/886.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/138.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/892.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/306.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/474.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/299.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/272.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/528.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/919.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/702.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/501.jpg이미지는 dog으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/273.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/298.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/449.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/475.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/307.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/887.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/139.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/663.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/850.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/10.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/688.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/844.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/878.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/38.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/21.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/861.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/35.jpg이미지는 cat로 추정됩니다.
# [0.998 0.002 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/685.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/691.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/120.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/652.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/493.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/444.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/322.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/336.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/450.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/256.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/242.jpg이미지는 dog으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/901.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/732.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/727.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/733.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/900.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/914.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/243.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/531.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/257.jpg이미지는 dog으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/519.jpg이미지는 rodent으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/280.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/294.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/337.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/451.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/323.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/479.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/486.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/653.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/121.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/109.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/690.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/684.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/874.jpg이미지는 dog으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/860.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/20.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/36.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/876.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/686.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/679.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/651.jpg이미지는 dog으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/123.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/490.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/484.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/309.jpg이미지는 dog으로 추정됩니다.
# [0.204 0.796 0.000]
# 1
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/321.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/447.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/296.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/269.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/241.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/533.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/902.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/719.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/731.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/730.jpg이미지는 cat로 추정됩니다.
# [0.000 0.984 0.016]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/724.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/718.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/917.jpg이미지는 cat로 추정됩니다.
# [0.000 0.232 0.768]
# 2
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/254.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/240.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/268.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/283.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/320.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/446.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/452.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/334.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/308.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/644.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/122.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/136.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/650.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/888.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/687.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/863.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/697.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/683.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/873.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/867.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/654.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/132.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/126.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/898.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/668.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/481.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/330.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/456.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/442.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/324.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/318.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/244.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/536.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/250.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/278.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/913.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/734.jpg이미지는 cat로 추정됩니다.
# [0.000 0.995 0.005]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/708.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/709.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/721.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/906.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/251.jpg이미지는 rodent으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/245.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/523.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/292.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/319.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/443.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/331.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/480.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/494.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/127.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/641.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/655.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/133.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/866.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/26.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/872.jpg이미지는 dog으로 추정됩니다.
# [0.999 0.000 0.001]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/682.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/696.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/680.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/18.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/858.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/694.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/24.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/870.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/643.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/125.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/131.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/496.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/327.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/455.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/333.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/469.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/290.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/521.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/247.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/938.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/904.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/737.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/723.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/722.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/736.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/905.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/911.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/520.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/252.jpg이미지는 rodent으로 추정됩니다.
# [0.281 0.719 0.000]
# 1
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/454.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/326.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/440.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/497.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/483.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/118.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/130.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/656.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/642.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/124.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/865.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/695.jpg이미지는 rodent으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/859.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/681.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/4.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/56.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/816.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/194.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/81.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/619.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/95.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/625.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/143.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/157.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/631.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/396.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/341.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/427.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/355.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/584.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/209.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/235.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/553.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/547.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/786.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/779.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/745.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/744.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/750.jpg이미지는 cat로 추정됩니다.
# [0.997 0.003 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/778.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/546.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/220.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/234.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/552.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/585.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/591.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/432.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/354.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/340.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/426.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/368.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/383.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/630.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/624.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/142.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/618.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/80.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/181.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/55.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/7.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/801.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/69.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/829.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/183.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/168.jpg이미지는 rodent으로 추정됩니다.
# [0.977 0.023 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/82.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/154.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/626.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/395.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/381.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/418.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/356.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/430.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/587.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/578.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/222.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/544.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/550.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/236.jpg이미지는 rodent으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/949.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/746.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/753.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/784.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/551.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/237.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/545.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/579.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/592.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/586.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/425.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/343.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/431.jpg이미지는 cat로 추정됩니다.
# [0.000 0.999 0.001]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/419.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/394.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/141.jpg이미지는 dog으로 추정됩니다.
# [0.992 0.008 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/627.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/633.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/155.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/83.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/97.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/182.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/828.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/196.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/54.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/6.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/192.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/78.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/50.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/810.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/44.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/804.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/151.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/637.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/623.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/145.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/93.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/390.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/435.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/353.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/596.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/541.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/227.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/233.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/555.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/569.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/780.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/743.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/757.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/568.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/554.jpg이미지는 dog으로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/540.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/597.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/346.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/434.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/352.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/385.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/391.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/86.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/178.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/92.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/622.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/150.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/45.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/3.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/811.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/51.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/839.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/187.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/193.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/191.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/53.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/634.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/152.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/608.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/90.jpg이미지는 cat로 추정됩니다.
# [0.002 0.998 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/387.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/344.jpg이미지는 cat로 추정됩니다.
# [0.000 0.038 0.962]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/350.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/595.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/581.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/556.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/230.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/783.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/740.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/768.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/769.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/741.jpg이미지는 cat로 추정됩니다.
# [0.100 0.900 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/755.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/225.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/543.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/557.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/580.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/594.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/379.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/351.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/423.jpg이미지는 rodent으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/392.jpg이미지는 dog으로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/386.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/85.jpg이미지는 cat로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/635.jpg이미지는 cat로 추정됩니다.
# [0.000 0.999 0.001]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/153.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/621.jpg이미지는 cat로 추정됩니다.
# [0.000 1.000 0.000]
# 1
# 해당 /Users/jiwon/Desktop/female/cat/812.jpg이미지는 dog으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/52.jpg이미지는 cat로 추정됩니다.
# [0.000 0.000 1.000]
# 2
# 해당 /Users/jiwon/Desktop/female/cat/46.jpg이미지는 rodent으로 추정됩니다.
# [1.000 0.000 0.000]
# 0
# 해당 /Users/jiwon/Desktop/female/cat/190.jpg이미지는 cat로 추정됩니다.
# [0.000 0.742 0.258]
# 1

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import os
import numpy as np
import PIL

np.set_printoptions(linewidth=1000)

def save_model(h5_path, model_path):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(10, activation='softmax', input_shape=[784]))

    model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,
                  metrics=['acc'])

    mnist = input_data.read_data_sets('mnist')
    model.fit(mnist.train.images, mnist.train.labels,
              validation_data=[mnist.validation.images, mnist.validation.labels],
              epochs=15, batch_size=128, verbose=0)

    model.save(h5_path)
    converter = tf.lite.TFLiteConverter.from_keras_model_file(h5_path)
    flat_data = converter.convert()

    with open(model_path, 'wb') as f:
        f.write(flat_data)

save_model('./mnist.h5', './mnist.tflite')
# Out:
# WARNING:tensorflow:From /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From <ipython-input-10-2d9a5ac35181>:17: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting mnist/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting mnist/train-labels-idx1-ubyte.gz
# Extracting mnist/t10k-images-idx3-ubyte.gz
# Extracting mnist/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/lite/python/util.py:238: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /Users/jiwon/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/graph_util_impl.py:270: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 2 variables.
# INFO:tensorflow:Converted 2 variables to const ops.

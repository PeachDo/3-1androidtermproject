# %%
import cv2, sys, re
import matplotlib.pyplot as plt

face_cascade = cv2.CascadeClassifier('/usr/local/Cellar/opencv/4.3.0_1/share/opencv4/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('/usr/local/Cellar/opencv/4.3.0_1/share/opencv4/haarcascades/haarcascade_eye.xml')

photo_num = int(input("Please enter the first photo number to crop: "))
count =  int(input("Please enter the last photo number to crop: "))

while photo_num <= count:    
    print("photo_num: " + str(photo_num))
    image_file = "/Users/jiwon/Documents/GitHub/Android_Term_Project_2020/Crawling/female/cat/" + str(photo_num) + ".jpg"
    # output_file = re.sub(r'\.jpg|jpeg|PNG$', '-output.jpg', '/Users/jiwon/Documents/GitHub/Android_Term_Project_2020/OpenCV/training/')
    output_file = '/Users/jiwon/Documents/GitHub/Android_Term_Project_2020/OpenCV/training/' + str(photo_num) +".jpg" 
    photo_num += 1 #현재 크롭(crop)할 사진 번호
    img = cv2.imread(image_file)
    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    cropped = None
    gray_cropped = None
    
    faces = face_cascade.detectMultiScale(gray, 1.3,5)
    for (x,y,w,h) in faces:
        try:
            cropped = img[y - int(h/15):y + h + int(h/15), x - int(w/15):x + w + int(w/15)]
            gray_cropped = cv2.cvtColor(cropped, cv2.COLOR_BGR2GRAY)
        except:
            print("Image not recognized")      
    # cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0),2)
    # roi_gray = gray[y:y+h, x:x+w]
    # roi_color = img[y:y+h, x:x+w]
    # eyes = eye_cascade.detectMultiScale(roi_gray)
    # for (ex, ey, ew, eh) in eyes:
    #    cv2.rectangle(roi_color, (ex,ey), (ex+ew, ey+eh),(0,255,0),2)
    # if cropped.all() and gray_cropped.all():
    try:
        cv2.imwrite(output_file, gray_cropped)
    except:
        print("Image not recognized")

        

# cv2.imshow('Image view', gray_cropped)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# Please enter the first photo number to crop: 906
# Please enter the last photo number to crop: 955
# photo_num: 906
# photo_num: 907
# Image not recognized
# photo_num: 908
# photo_num: 909
# Image not recognized
# photo_num: 910
# Image not recognized
# photo_num: 911
# photo_num: 912
# Image not recognized
# photo_num: 913
# photo_num: 914
# photo_num: 915
# Image not recognized
# photo_num: 916
# Image not recognized
# photo_num: 917
# photo_num: 918
# Image not recognized
# photo_num: 919
# photo_num: 920
# photo_num: 921
# Image not recognized
# photo_num: 922
# photo_num: 923
# Image not recognized
# photo_num: 924
# Image not recognized
# photo_num: 925
# Image not recognized
# photo_num: 926
# Image not recognized
# photo_num: 927
# photo_num: 928
# Image not recognized
# photo_num: 929
# Image not recognized
# photo_num: 930
# Image not recognized
# photo_num: 931
# Image not recognized
# photo_num: 932
# photo_num: 933
# Image not recognized
# photo_num: 934
# Image not recognized
# photo_num: 935
# Image not recognized
# photo_num: 936
# photo_num: 937
# Image not recognized
# photo_num: 938
# photo_num: 939
# Image not recognized
# photo_num: 940
# photo_num: 941
# photo_num: 942
# photo_num: 943
# photo_num: 944
# Image not recognized
# photo_num: 945
# Image not recognized
# photo_num: 946
# Image not recognized
# photo_num: 947
# photo_num: 948
# Image not recognized
# photo_num: 949
# photo_num: 950
# Image not recognized
# photo_num: 951
# photo_num: 952
# photo_num: 953
# Image not recognized
# photo_num: 954
# photo_num: 955
# Image not recognized

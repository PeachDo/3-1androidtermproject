# %%
import cv2, sys, re
import matplotlib.pyplot as plt

face_cascade = cv2.CascadeClassifier('/usr/local/Cellar/opencv/4.3.0_1/share/opencv4/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('/usr/local/Cellar/opencv/4.3.0_1/share/opencv4/haarcascades/haarcascade_eye.xml')

photo_num = int(input("Please enter the first photo number to crop: "))
count =  int(input("Please enter the last photo number to crop: "))

# File name must be number

while photo_num <= count:    
    print("photo_num: " + str(photo_num))
    image_file = "/Users/jiwon/Documents/GitHub/Android_Term_Project_2020/Crawling/female/dog/" + str(photo_num) + ".jpg"
    # output_file = re.sub(r'\.jpg|jpeg|PNG$', '-output.jpg', '/Users/jiwon/Documents/GitHub/Android_Term_Project_2020/OpenCV/training/')
    output_file = '/Users/jiwon/Documents/GitHub/Android_Term_Project_2020/OpenCV/training/female/dog/' + str(photo_num) +".jpg" 
    photo_num += 1 #현재 크롭(crop)할 사진 번호
    img = cv2.imread(image_file)
    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    cropped = None
    gray_cropped = None
    
    faces = face_cascade.detectMultiScale(gray, 1.3,5)
    for (x,y,w,h) in faces:
        try:
            cropped = img[y - int(h/15):y + h + int(h/15), x - int(w/15):x + w + int(w/15)]
            gray_cropped = cv2.cvtColor(cropped, cv2.COLOR_BGR2GRAY)
        except:
            print("Image not recognized")      
    # cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0),2)
    # roi_gray = gray[y:y+h, x:x+w]
    # roi_color = img[y:y+h, x:x+w]
    # eyes = eye_cascade.detectMultiScale(roi_gray)
    # for (ex, ey, ew, eh) in eyes:
    #    cv2.rectangle(roi_color, (ex,ey), (ex+ew, ey+eh),(0,255,0),2)
    # if cropped.all() and gray_cropped.all():
    try:
        cv2.imwrite(output_file, gray_cropped)
    except:
        print("Image not recognized")

        

# cv2.imshow('Image view', gray_cropped)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# Please enter the first photo number to crop: 1
# Please enter the last photo number to crop: 999
# photo_num: 1
# photo_num: 2
# photo_num: 3
# photo_num: 4
# photo_num: 5
# Image not recognized
# photo_num: 6
# photo_num: 7
# Image not recognized
# photo_num: 8
# Image not recognized
# photo_num: 9
# photo_num: 10
# photo_num: 11
# Image not recognized
# photo_num: 12
# photo_num: 13
# photo_num: 14
# photo_num: 15
# Image not recognized
# photo_num: 16
# Image not recognized
# photo_num: 17
# Image not recognized
# photo_num: 18
# photo_num: 19
# Image not recognized
# photo_num: 20
# Image not recognized
# photo_num: 21
# Image not recognized
# photo_num: 22
# Image not recognized
# photo_num: 23
# photo_num: 24
# photo_num: 25
# photo_num: 26
# Image not recognized
# photo_num: 27
# Image not recognized
# photo_num: 28
# Image not recognized
# photo_num: 29
# Image not recognized
# photo_num: 30
# photo_num: 31
# photo_num: 32
# Image not recognized
# photo_num: 33
# ...
